# %% [markdown]
# ![MLU Logo](https://drive.corp.amazon.com/view/bwernes@/MLU_Logo.png?download=true)

# %% [markdown]
# # MLA Tabular Data - Final Project: Product Substitute Prediction
# # Day 1: Data Processing and Developing ML Model
# ___
# ### Problem Definition:
# Given a pair of products, (A, B), we say that B is a "substitute" for A if a customer would buy B in place of A -- say, if A were out of stock.
#
# The goal of this project is to predict a substitute relationship between pairs of products. Complete the tasks in this notebook and submit your result CSV file to the leaderboard: __https://leaderboard.corp.amazon.com/tasks/478__
#
# ### __Dataset and Files:__
#
# * __asin_product_data.csv__: Each line gives a specific product information such as ASIN, category, item name, etc. We will use this to create a feature vector for each product. This file has 113 columns, we will try to select some useful columns in this notebook because not all of them are suitable. `|Region Id|MarketPlace Id|ASIN|Binding Code|binding_description|brand_code|case_pack_quantity|, ...`
#
#
# * __dataset_metadata.csv__: Provides detailed information about all 113 columns in the asin_product_data.csv
#
#
# * __training.csv__: Product pairs to consider are given here. Its columns are:
# > - `ID:` ID of the record
# > - `key_asin:` Key product ASIN
# > - `cand_asin:` Candidate product ASIN
# > - `label:` Tells whether the key and candidate products are susbstitutes (1) or not (0).
#
# * __Sample submission file:__ You can downlad a sample file from [here](https://leaderboard.corp.amazon.com/datasets/1469)

# %% [markdown]
# ___
# ## 1. Reading the Dataset

# %%
import boto3
from os import path
import pandas as pd

# import the datasets
bucketname = 'mlu-student-datalake' # replace with your bucket name
filename1 = 'MLA-TAB/asin_product.csv' # replace with your object key
filename2 = 'MLA-TAB/training.csv' # replace with your object key
filename3 = 'MLA-TAB/public_test_features.csv' # replace with your object key
s3 = boto3.resource('s3')
if not path.exists("asin_product.csv"):
    s3.Bucket(bucketname).download_file(filename1, 'asin_product.csv')
if not path.exists("training.csv"):
    s3.Bucket(bucketname).download_file(filename2, 'training.csv')
if not path.exists("public_test_features.csv"):
    s3.Bucket(bucketname).download_file(filename3, 'public_test_features.csv')
    
asin_product_data = pd.read_csv('asin_product.csv', encoding='ISO-8859-1')
training_data = pd.read_csv('training.csv')
test_data = pd.read_csv('public_test_features.csv')
#env.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (18,19,23,31,38,41,48,63,78,82,85,96,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Let's see what our data looks like below:
#
# __"asin_product_data.csv"__ file gives us information about products. We will use this as our main data table to construct feature vectors for each ASIN (product) in our training and test datasets

# %%
asin_product_data.head()
# Out:
#    Region Id  MarketPlace Id        ASIN Binding Code binding_description  \
# 0          1               1   153427507    hardcover           Hardcover
# 1          1               1   267648340    hardcover           Hardcover
# 2          1               1   545496470    hardcover           Hardcover
# 3          1               1   679858040    paperback           Paperback
# 4          1               1  078694742X          toy                 Toy
#
#   brand_code  case_pack_quantity classification_code  \
# 0        NaN                 NaN        base_product
# 1      FOS3T                 NaN        base_product
# 2      KLUTZ                 6.0        base_product
# 3        NaN                 NaN        base_product
# 4      WZDCS                12.0        base_product
#
#   classification_description color_map  ... pkg_weight pkg_weight_uom  \
# 0               Base Product       NaN  ...        NaN            NaN
# 1               Base Product       NaN  ...   0.850000         pounds
# 2               Base Product     Black  ...   1.631404         pounds
# 3               Base Product       NaN  ...   1.200000         pounds
# 4               Base Product       NaN  ...   0.620000         pounds
#
#   pkg_width release_date_embargo_level dw_creation_date dw_last_updated  \
# 0       NaN                        NaN         4-Jan-11       22-Jul-16
# 1  5.980000                        NaN        16-Sep-16       23-Feb-18
# 2  8.267717                        low        20-Aug-12       23-Dec-17
# 3  7.700000                        NaN         4-Jan-11        4-Nov-17
# 4  6.535433                        NaN         4-Jan-11       21-Oct-17
#
#    is_deleted  last_updated version external_testing_certification
# 0           N     21-Jul-16     145                            NaN
# 1           N     22-Feb-18      33                            NaN
# 2           N     23-Dec-17   20912                            NaN
# 3           N      3-Nov-17    2108                            NaN
# 4           N     20-Oct-17    9395                            NaN
#
# [5 rows x 112 columns]

# %% [markdown]
# __"training.csv"__ file is our training data. This file has a label 1 if the two products are subsitutes to each other and 0 otherwise.

# %%
training_data.head()
# Out:
#       ID    key_asin   cand_asin  label
# 0  42595  B01L7CFUWC  B01CU4SOQ0      1
# 1  35775  B01KDAKKTM  B01CGQE5YC      0
# 2  37152  B013FA0UVA  B06W9HY6MV      1
# 3   4340  B008KPZLEC  B01M5AMNA1      0
# 4  37349  B0196BJHXY  B00XCHMLI2      1

# %% [markdown]
# __"public_test_features.csv"__ file is the test data. Let's see what it looks like. See below that we don't have the label column in this data. We will predict the labels with our Machine Learning model.

# %%
test_data.head()
# Out:
#       ID    key_asin   cand_asin
# 0  39236  B01C5TFLSE  B06XDMZ5MY
# 1   1353  B003YJ8TVQ  B01G6R24CM
# 2  39280  B0063X7BT6  B01BO2NOD2
# 3   1665  B01DJH637O  B017SCJACQ
# 4  14925  B003U8ESI4  B00HGDMGM4

# %% [markdown]
# _____
# ## 2. Exploratory Data Analysis and Feature Engineering

# %% [markdown]
# As you can see the from the __"asin_product_data.head()"__ result above, we are dealing with a lot of columns. Each column is a potential feature for our problem. As we don't know how to deal with text and categorical columns yet, we will only consider numerical columns in this first submission.

# %%
# categorical columns include "ASIN", "item_package_quantity", "pkg_height", "pkg_length", "pkg_weight"
asin_product_data.isna().sum()
# Out:
# Region Id                             0
# MarketPlace Id                        0
# ASIN                                  0
# Binding Code                      10072
# binding_description               10072
# brand_code                        45368
# case_pack_quantity                44866
# classification_code                   1
# classification_description            1
# color_map                         46490
# cpsia_cautionary_statement        55653
# creation_date                         0
# currency_code                         0
# customer_return_method            65091
# customer_return_policy            61869
# delivery_option                   63364
# discontinued_date                 65715
# ean                               11445
# esrb_age_rating                   65624
# esrb_descriptors                  65713
# excluded_direct_browse_node_id    53635
# fedas_id                          65702
# fma_qualified_price_max           14540
# fma_override                      65695
# Product Group Code                    0
# Product Group Description             0
# has_ean                               0
# has_online_play                       0
# has_platform                          0
# has_recommended_browse_nodes          0
#                                   ...
# publisher                         65713
# publisher_code                    44084
# publisher_studio_label             4370
# recall_description                65409
# recall_external_identifier        65715
# recall_notice_expiration_date     65715
# recall_notice_publication_date    65715
# recall_notice_receive_date        65715
# target_gender                     60100
# unit_count                        57287
# upc                               17458
# variation_theme_description       40230
# variation_theme_id                40230
# video_game_region                 65695
# video_game_region_description     65695
# wireless_provider                 65497
# wireless_provider_code            65497
# pkg_dimensional_uom               13327
# pkg_height                        13327
# pkg_length                        13327
# pkg_weight                        13794
# pkg_weight_uom                    13794
# pkg_width                         13327
# release_date_embargo_level        65546
# dw_creation_date                      0
# dw_last_updated                       0
# is_deleted                            0
# last_updated                          0
# version                               0
# external_testing_certification    64682
# Length: 112, dtype: int64

# %% [markdown]
# Let's select numerical features below

# %%
#replacing missing values with mean for now
asin_product_data["item_package_quantity"].fillna(asin_product_data["item_package_quantity"].mean(), inplace=True)
asin_product_data["item_height"].fillna(asin_product_data["item_height"].mean(), inplace=True)
asin_product_data["item_width"].fillna(asin_product_data["item_width"].mean(), inplace=True)
asin_product_data["item_length"].fillna(asin_product_data["item_length"].mean(), inplace=True)
asin_product_data["item_weight"].fillna(asin_product_data["item_weight"].mean(), inplace=True)
asin_product_data["pkg_height"].fillna(asin_product_data["pkg_height"].mean(), inplace=True)
asin_product_data["pkg_width"].fillna(asin_product_data["pkg_width"].mean(), inplace=True)
asin_product_data["pkg_length"].fillna(asin_product_data["pkg_length"].mean(), inplace=True)
asin_product_data["pkg_weight"].fillna(asin_product_data["pkg_weight"].mean(), inplace=True)

# %%
# re-cheking the replaced values
asin_product_data.isna().sum()
# Out:
# Region Id                             0
# MarketPlace Id                        0
# ASIN                                  0
# Binding Code                      10072
# binding_description               10072
# brand_code                        45368
# case_pack_quantity                44866
# classification_code                   1
# classification_description            1
# color_map                         46490
# cpsia_cautionary_statement        55653
# creation_date                         0
# currency_code                         0
# customer_return_method            65091
# customer_return_policy            61869
# delivery_option                   63364
# discontinued_date                 65715
# ean                               11445
# esrb_age_rating                   65624
# esrb_descriptors                  65713
# excluded_direct_browse_node_id    53635
# fedas_id                          65702
# fma_qualified_price_max           14540
# fma_override                      65695
# Product Group Code                    0
# Product Group Description             0
# has_ean                               0
# has_online_play                       0
# has_platform                          0
# has_recommended_browse_nodes          0
#                                   ...
# publisher                         65713
# publisher_code                    44084
# publisher_studio_label             4370
# recall_description                65409
# recall_external_identifier        65715
# recall_notice_expiration_date     65715
# recall_notice_publication_date    65715
# recall_notice_receive_date        65715
# target_gender                     60100
# unit_count                        57287
# upc                               17458
# variation_theme_description       40230
# variation_theme_id                40230
# video_game_region                 65695
# video_game_region_description     65695
# wireless_provider                 65497
# wireless_provider_code            65497
# pkg_dimensional_uom               13327
# pkg_height                            0
# pkg_length                            0
# pkg_weight                            0
# pkg_weight_uom                    13794
# pkg_width                             0
# release_date_embargo_level        65546
# dw_creation_date                      0
# dw_last_updated                       0
# is_deleted                            0
# last_updated                          0
# version                               0
# external_testing_certification    64682
# Length: 112, dtype: int64

# %% [markdown]
# ___
# ## 3. Creating the feature map
#
# We are giving you a helper function here. Because of the nature of our training and test data, we need to map ASIN's to their feaures. For this reason, we will use a dictionary variable named __feature_map__. The main advantage of this is fast lookup time when we are putting together the training and test features

# %% [markdown]
# We completed constructing our features for each product in section 2. If you used the given columns, you will have 4 numeric features for each product. The code below maps ASINs to these features.
#
# Let's print our dataframe below.

# %%
asin_product_data.head()
# Out:
#    Region Id  MarketPlace Id        ASIN Binding Code binding_description  \
# 0          1               1   153427507    hardcover           Hardcover
# 1          1               1   267648340    hardcover           Hardcover
# 2          1               1   545496470    hardcover           Hardcover
# 3          1               1   679858040    paperback           Paperback
# 4          1               1  078694742X          toy                 Toy
#
#   brand_code  case_pack_quantity classification_code  \
# 0        NaN                 NaN        base_product
# 1      FOS3T                 NaN        base_product
# 2      KLUTZ                 6.0        base_product
# 3        NaN                 NaN        base_product
# 4      WZDCS                12.0        base_product
#
#   classification_description color_map  ... pkg_weight pkg_weight_uom  \
# 0               Base Product       NaN  ...   6.236240            NaN
# 1               Base Product       NaN  ...   0.850000         pounds
# 2               Base Product     Black  ...   1.631404         pounds
# 3               Base Product       NaN  ...   1.200000         pounds
# 4               Base Product       NaN  ...   0.620000         pounds
#
#   pkg_width release_date_embargo_level dw_creation_date dw_last_updated  \
# 0  7.714382                        NaN         4-Jan-11       22-Jul-16
# 1  5.980000                        NaN        16-Sep-16       23-Feb-18
# 2  8.267717                        low        20-Aug-12       23-Dec-17
# 3  7.700000                        NaN         4-Jan-11        4-Nov-17
# 4  6.535433                        NaN         4-Jan-11       21-Oct-17
#
#    is_deleted  last_updated version external_testing_certification
# 0           N     21-Jul-16     145                            NaN
# 1           N     22-Feb-18      33                            NaN
# 2           N     23-Dec-17   20912                            NaN
# 3           N      3-Nov-17    2108                            NaN
# 4           N     20-Oct-17    9395                            NaN
#
# [5 rows x 112 columns]

# %%
feature_map = {}

for index, row in asin_product_data.iterrows():
    # load all features in (some are useless)
    feature_map[row["ASIN"]] = row.tolist()

# %%
# Test: This should work if the mapper is correctly created
print(feature_map["1785245481"])
# Out:
# [1, 1, '1785245481', 'office_product', 'Office Product', nan, nan, 'base_product', 'Base Product', nan, nan, '24-Feb-16', 'USD', nan, nan, nan, nan, 9780000000000.0, nan, nan, nan, nan, 26.31, nan, 229, 'gl_office_product', 'Y', 'N', 'N', 'N', 'N', nan, nan, 'N', nan, 'Y', 'N', 'N', nan, 'Y', nan, '1785245481', 1.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, 0.25, 11.81, 'Inspirational Quotes, Notable Quotables 2017 Monthly Wall Calendar, 12" x 12"', 1.0, 0.5, 11.81, 'en_US', 'The Gifted Stationary Co', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'OFFICE_PRODUCTS', 3523, nan, nan, nan, nan, nan, nan, nan, nan, 'The Gifted Stationary Co', nan, nan, nan, nan, nan, nan, nan, nan, 'COLOR', 2.0, nan, nan, nan, nan, 'inches', 0.25, 11.81199999, 0.5, 'pounds', 11.81199999, nan, '25-Feb-16', '9-Jun-17', 'N', '9-Jun-17', 69, nan]

# %% [markdown]
# ___
# ## 4. Getting features
#
# We provide the __getFeatures()__ function below. We will get training and test features with this function.
#
# In this function, we are concatenating key product features and candidate product features. For example:
# key_asin_feature = [0.12, 2.5, 1, 4.2] and cand_asin_feature = [0.5, 0.1, 3.2, 2.75] results in [0.12, 2.5, 1, 4.2, 0.5, 0.1, 3.2, 2.75]

# %%
def getFeatures(data_df, feature_map):
    features = []
    for index, row in data_df.iterrows():
        key_features = feature_map[row["key_asin"]]
        cand_features = feature_map[row["cand_asin"]]
        
        # Concatenate feature vectors
        concat_features = key_features + cand_features
        features.append(concat_features)
        
    return features

# %% [markdown]
# Let's use this function twice to get our training and test features.

# %%
train_features = getFeatures(training_data, feature_map)
test_features = getFeatures(test_data, feature_map)

# %%
# create column names for features dataframes
key_columns = ['key_' + val for val in asin_product_data.columns]
cand_columns = ['cand_' + val for val in asin_product_data.columns]
concat_columns = key_columns + cand_columns

training_features_df = pd.DataFrame(train_features, columns=concat_columns)

pd.set_option('display.max_columns', None)
training_features_df.head()
# Out:
#    key_Region Id  key_MarketPlace Id    key_ASIN   key_Binding Code  \
# 0              1                   1  B01L7CFUWC                NaN
# 1              1                   1  B01KDAKKTM       baby_product
# 2              1                   1  B013FA0UVA                toy
# 3              1                   1  B008KPZLEC  health_and_beauty
# 4              1                   1  B0196BJHXY            kitchen
#
#   key_binding_description key_brand_code  key_case_pack_quantity  \
# 0                     NaN            NaN                     NaN
# 1            Baby Product            NaN                     NaN
# 2                     Toy          POKB7                     1.0
# 3       Health and Beauty            NaN                     NaN
# 4                 Kitchen          CRCF7                     NaN
#
#   key_classification_code key_classification_description key_color_map  \
# 0            base_product                   Base Product           NaN
# 1            base_product                   Base Product         White
# 2            base_product                   Base Product           NaN
# 3            base_product                   Base Product           NaN
# 4            base_product                   Base Product           Red
#
#   key_cpsia_cautionary_statement key_creation_date key_currency_code  \
# 0                            NaN         29-Aug-16               USD
# 1                            NaN         14-Aug-16               USD
# 2                            NaN          4-Aug-15               USD
# 3                            NaN         12-Jul-12               USD
# 4                            NaN         10-Dec-15               USD
#
#   key_customer_return_method key_customer_return_policy key_delivery_option  \
# 0                        NaN                        NaN                 NaN
# 1                        NaN                        NaN                 NaN
# 2                        NaN                        NaN                 NaN
# 3                        NaN                        NaN                 NaN
# 4                        NaN                        NaN                 NaN
#
#    key_discontinued_date       key_ean key_esrb_age_rating  \
# 0                    NaN           NaN                 NaN
# 1                    NaN  7.020000e+11                 NaN
# 2                    NaN  4.170000e+12                 NaN
# 3                    NaN  8.540000e+11                 NaN
# 4                    NaN  4.889406e+10                 NaN
#
#   key_esrb_descriptors  key_excluded_direct_browse_node_id  key_fedas_id  \
# 0                  NaN                                 NaN           NaN
# 1                  NaN                                 NaN           NaN
# 2                  NaN                                 NaN           NaN
# 3                  NaN                            228013.0           NaN
# 4                  NaN                                 NaN           NaN
#
#    key_fma_qualified_price_max key_fma_override  key_Product Group Code  \
# 0                        35.17              NaN                      60
# 1                        29.40              NaN                      75
# 2                        34.29              NaN                      21
# 3                        37.23              NaN                     121
# 4                        83.46              NaN                      79
#
#   key_Product Group Description key_has_ean key_has_online_play  \
# 0           gl_home_improvement           N                   N
# 1               gl_baby_product           Y                   N
# 2                        gl_toy           Y                   N
# 3                  gl_drugstore           Y                   N
# 4                    gl_kitchen           Y                   N
#
#   key_has_platform key_has_recommended_browse_nodes key_has_upc  \
# 0                N                                N           N
# 1                N                                N           Y
# 2                N                                N           Y
# 3                N                                N           Y
# 4                N                                N           Y
#
#   key_inner_package_type key_is_adult_product key_is_advantage  \
# 0                    NaN                  NaN                N
# 1                    NaN                    N                N
# 2                    NaN                    N                N
# 3                    NaN                    N                N
# 4                    NaN                  NaN                N
#
#   key_is_certified_organic key_is_conveyable key_is_discontinued  \
# 0                      NaN                 Y                   N
# 1                      NaN                 Y                   N
# 2                      NaN                 Y                   N
# 3                      NaN                 Y                   N
# 4                      NaN                 Y                   N
#
#   key_is_manufacture_on_demand key_is_phone_upgradeable key_Is Sortable  \
# 0                            N                      NaN               Y
# 1                            N                      NaN               Y
# 2                            N                      NaN               Y
# 3                            N                      NaN               Y
# 4                            N                      NaN               N
#
#   key_is_super_saver_shipping_excl key_isbn  key_item_classification_id  \
# 0                              NaN      NaN                         1.0
# 1                              NaN      NaN                         1.0
# 2                              NaN      NaN                         1.0
# 3                              NaN      NaN                         1.0
# 4                              NaN      NaN                         1.0
#
#    key_item_display_diameter  key_item_display_height  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    key_item_display_length key_item_display_length_uom  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#    key_item_display_volume key_item_display_volume_uom  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#    key_item_display_weight key_item_display_weight_uom  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      0.2                      pounds
# 4                      NaN                         NaN
#
#    key_item_display_width  key_item_height  key_item_length  \
# 0                     NaN         0.039370         0.039370
# 1                     NaN         3.000000         2.000000
# 2                     NaN         2.000000         9.250000
# 3                     NaN      1045.436025        15.782868
# 4                     NaN        14.800000         9.400000
#
#                                        key_item_name  \
# 0  KINGSO E26/ E27 Pendant Light Triple Lamp Sock...
# 1  Hawaiian Fish Hook Pendant Silicone Teething N...
# 2  TCG: Shiny Rayquaza-EX Box Card Game (Disconti...
# 3  LifeSeasons Metabolism Weight Control - Natura...
# 4  Crock-pot SCCPVL610-R-A 6-Quart Programmable C...
#
#    key_item_package_quantity  key_item_weight  key_item_width  \
# 0                        1.0         0.000220        0.039370
# 1                        1.0         7.098467        0.380000
# 2                        1.0         0.639341       13.000000
# 3                        1.0         0.200000       10.503185
# 4                        1.0         7.098467       15.100000
#
#   key_language_code           key_manufacturer_name  key_manufacturer_sku  \
# 0             en_US                          KINGSO                   NaN
# 1             en_US  Glorified Enterprises USA, LLC                   NaN
# 2             en_US                             R&M                   NaN
# 3             en_US                     LifeSeasons                   NaN
# 4             en_US                       Crock-pot                   NaN
#
#   key_manufacturer_vendor_code  key_max_weight_recommendation  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                        RMAAD                            NaN
# 3                          NaN                            NaN
# 4                        OSTE9                            NaN
#
#   key_mfg_series_number  key_min_weight_recommendation key_model_number  \
# 0                   NaN                            NaN              NaN
# 1                   NaN                            NaN              NaN
# 2                   NaN                            NaN        290-80016
# 3                   NaN                            NaN              NaN
# 4                   NaN                            NaN    SCCPVL610-R-A
#
#    key_monthly_recurring_charge  key_number_of_items  key_number_of_licenses  \
# 0                           NaN                  NaN                     NaN
# 1                           NaN                  NaN                     NaN
# 2                           NaN                  NaN                     NaN
# 3                           NaN                  NaN                     NaN
# 4                           NaN                  NaN                     NaN
#
#    key_number_of_pages  key_number_of_points      key_ordering_channel  \
# 0                  NaN                   NaN                       NaN
# 1                  NaN                   NaN                       NaN
# 2                  NaN                   NaN      toy_ordering_channel
# 3                  NaN                   NaN                       NaN
# 4                  NaN                   NaN  kitchen_ordering_channel
#
#    key_preferred_vendor key_product_sample_received_day  \
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                        9-Dec-15
# 3                   NaN                             NaN
# 4                   NaN                             NaN
#
#           key_product_type  key_product_type_id key_program_member  \
# 0  HOME_LIGHTING_AND_LAMPS                  930                NaN
# 1             BABY_PRODUCT                 6336                NaN
# 2           TOYS_AND_GAMES                 6335                NaN
# 3     HEALTH_PERSONAL_CARE                 1203                NaN
# 4                  KITCHEN                 6419                NaN
#
#   key_program_member_code key_publication_date  key_publication_day  \
# 0                     NaN                  NaN                  NaN
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
#
#    key_publication_month  key_publication_year  key_publisher  \
# 0                    NaN                   NaN            NaN
# 1                    NaN                   NaN            NaN
# 2                    NaN                   NaN            NaN
# 3                    NaN                   NaN            NaN
# 4                    NaN                   NaN            NaN
#
#   key_publisher_code      key_publisher_studio_label  \
# 0                NaN                          KINGSO
# 1                NaN  Glorified Enterprises USA, LLC
# 2              RMAAD                             R&M
# 3                NaN                     LifeSeasons
# 4              OSTE9                       Crock-pot
#
#          key_recall_description  key_recall_external_identifier  \
# 0  Product Safety Investigation                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    key_recall_notice_expiration_date  key_recall_notice_publication_date  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    key_recall_notice_receive_date key_target_gender  key_unit_count  \
# 0                             NaN               NaN             NaN
# 1                             NaN               NaN             NaN
# 2                             NaN            unisex             NaN
# 3                             NaN               NaN            70.0
# 4                             NaN               NaN             NaN
#
#         key_upc key_variation_theme_description  key_variation_theme_id  \
# 0           NaN                           COLOR                     2.0
# 1  7.020000e+11                             NaN                     NaN
# 2  6.170000e+11                             NaN                     NaN
# 3  8.540000e+11                            SIZE                     1.0
# 4  4.889406e+10                      COLOR_NAME                     8.0
#
#    key_video_game_region key_video_game_region_description  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#   key_wireless_provider key_wireless_provider_code key_pkg_dimensional_uom  \
# 0                   NaN                        NaN                  inches
# 1                   NaN                        NaN                  inches
# 2                   NaN                        NaN                  inches
# 3                   NaN                        NaN                  inches
# 4                   NaN                        NaN                  inches
#
#    key_pkg_height  key_pkg_length  key_pkg_weight key_pkg_weight_uom  \
# 0        6.100000        8.700000        0.690000             pounds
# 1        0.250000        5.500000        0.030000             pounds
# 2        1.299213       13.188976        0.573202             pounds
# 3        2.200000        4.700000        0.250000             pounds
# 4        9.015748       15.511811       13.549611             pounds
#
#    key_pkg_width key_release_date_embargo_level key_dw_creation_date  \
# 0       7.000000                            NaN            30-Aug-16
# 1       4.500000                            NaN            14-Aug-16
# 2       9.409449                            NaN             5-Aug-15
# 3       2.300000                            NaN            13-Jul-12
# 4      15.000000                            NaN            10-Dec-15
#
#   key_dw_last_updated key_is_deleted key_last_updated  key_version  \
# 0            7-Feb-18              N         6-Feb-18           49
# 1           21-Apr-17              N        20-Apr-17           50
# 2           10-Mar-18              N         9-Mar-18         5706
# 3           22-Mar-18              N        21-Mar-18          466
# 4           23-Jan-18              N        23-Jan-18         1399
#
#   key_external_testing_certification  cand_Region Id  cand_MarketPlace Id  \
# 0                                NaN               1                    1
# 1                                NaN               1                    1
# 2                                NaN               1                    1
# 3                                NaN               1                    1
# 4                                NaN               1                    1
#
#     cand_ASIN cand_Binding Code cand_binding_description cand_brand_code  \
# 0  B01CU4SOQ0               NaN                      NaN             NaN
# 1  B01CGQE5YC               NaN                      NaN             NaN
# 2  B06W9HY6MV               toy                      Toy             NaN
# 3  B01M5AMNA1     miscellaneous                    Misc.             NaN
# 4  B00XCHMLI2               NaN                      NaN             NaN
#
#    cand_case_pack_quantity cand_classification_code  \
# 0                      NaN             base_product
# 1                      NaN             base_product
# 2                      NaN             base_product
# 3                      NaN             base_product
# 4                      NaN             base_product
#
#   cand_classification_description cand_color_map  \
# 0                    Base Product         7 Head
# 1                    Base Product            NaN
# 2                    Base Product            NaN
# 3                    Base Product            NaN
# 4                    Base Product            NaN
#
#   cand_cpsia_cautionary_statement cand_creation_date cand_currency_code  \
# 0                             NaN          11-Mar-16                USD
# 1                             NaN           2-Mar-16                USD
# 2                             NaN          13-Feb-17                USD
# 3                             NaN          12-Oct-16                USD
# 4                             NaN           8-May-15                USD
#
#   cand_customer_return_method cand_customer_return_policy  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   cand_delivery_option  cand_discontinued_date      cand_ean  \
# 0                  NaN                     NaN  7.420000e+11
# 1                  NaN                     NaN           NaN
# 2                  NaN                     NaN  7.220000e+11
# 3                  NaN                     NaN  8.150000e+11
# 4                  NaN                     NaN  7.980000e+11
#
#   cand_esrb_age_rating  cand_esrb_descriptors  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#    cand_excluded_direct_browse_node_id  cand_fedas_id  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
#
#    cand_fma_qualified_price_max cand_fma_override  cand_Product Group Code  \
# 0                         74.95               NaN                       60
# 1                           NaN               NaN                      517
# 2                           NaN               NaN                       21
# 3                         61.32               NaN                      194
# 4                         92.93               NaN                       79
#
#   cand_Product Group Description cand_has_ean cand_has_online_play  \
# 0            gl_home_improvement            Y                    N
# 1                       gl_guild            N                    N
# 2                         gl_toy            Y                    N
# 3                      gl_beauty            Y                    N
# 4                     gl_kitchen            Y                    N
#
#   cand_has_platform cand_has_recommended_browse_nodes cand_has_upc  \
# 0                 N                                 N            Y
# 1                 N                                 N            N
# 2                 N                                 N            Y
# 3                 N                                 N            Y
# 4                 N                                 N            Y
#
#   cand_inner_package_type cand_is_adult_product cand_is_advantage  \
# 0                     NaN                   NaN                 N
# 1                     NaN                     N                 N
# 2                     NaN                     N                 N
# 3                     NaN                     N                 N
# 4                     NaN                   NaN                 N
#
#   cand_is_certified_organic cand_is_conveyable cand_is_discontinued  \
# 0                       NaN                  Y                    N
# 1                       NaN                  Y                    N
# 2                       NaN                  Y                    N
# 3                       NaN                  Y                    N
# 4                       NaN                  Y                    N
#
#   cand_is_manufacture_on_demand cand_is_phone_upgradeable cand_Is Sortable  \
# 0                             N                       NaN                Y
# 1                             N                       NaN                Y
# 2                             N                       NaN                Y
# 3                             N                       NaN                Y
# 4                             N                       NaN                N
#
#   cand_is_super_saver_shipping_excl cand_isbn  cand_item_classification_id  \
# 0                               NaN       NaN                          1.0
# 1                               NaN       NaN                          1.0
# 2                               NaN       NaN                          1.0
# 3                               NaN       NaN                          1.0
# 4                               NaN       NaN                          1.0
#
#    cand_item_display_diameter  cand_item_display_height  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    cand_item_display_length cand_item_display_length_uom  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    cand_item_display_volume cand_item_display_volume_uom  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    cand_item_display_weight cand_item_display_weight_uom  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    cand_item_display_width  cand_item_height  cand_item_length  \
# 0                      NaN         11.000000         10.800000
# 1                      NaN       1045.436025         15.782868
# 2                      NaN          0.300000         11.000000
# 3                      NaN       1045.436025         15.782868
# 4                      NaN       1045.436025         15.782868
#
#                                       cand_item_name  \
# 0  Lightess Pendant Lights Vintage Multi Cord Edi...
# 1  Chew Necklace for Boys/Sensory Necklace/Toddle...
# 2  Pokemon Oversize Card Lot - 4 Oversize Promo C...
# 3                               Ouai Finishing Crème
# 4            Crock-Pot 7-qt. Slow Cooker (Turquoise)
#
#    cand_item_package_quantity  cand_item_weight  cand_item_width  \
# 0                    1.000000          2.800000         5.100000
# 1                    4.025675          7.098467        10.503185
# 2                    4.025675          7.098467         8.500000
# 3                    1.000000          0.264555        10.503185
# 4                    1.000000         12.720673        10.503185
#
#   cand_language_code cand_manufacturer_name  cand_manufacturer_sku  \
# 0              en_US               Lightess                    NaN
# 1              en_US                    NaN                    NaN
# 2              en_US                Pokemon                    NaN
# 3              en_US                    NaN                    NaN
# 4              en_US                    NaN                    NaN
#
#   cand_manufacturer_vendor_code  cand_max_weight_recommendation  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#   cand_mfg_series_number  cand_min_weight_recommendation cand_model_number  \
# 0                    NaN                             NaN               NaN
# 1                    NaN                             NaN               NaN
# 2                    NaN                             NaN               NaN
# 3                    NaN                             NaN               NaN
# 4                    NaN                             NaN   COMIN16JU032690
#
#    cand_monthly_recurring_charge  cand_number_of_items  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
#
#    cand_number_of_licenses  cand_number_of_pages  cand_number_of_points  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
#
#   cand_ordering_channel  cand_preferred_vendor  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
#
#   cand_product_sample_received_day        cand_product_type  \
# 0                              NaN  HOME_LIGHTING_AND_LAMPS
# 1                              NaN            GUILD_JEWELRY
# 2                              NaN           TOYS_AND_GAMES
# 3                              NaN                   BEAUTY
# 4                              NaN                  KITCHEN
#
#    cand_product_type_id cand_program_member cand_program_member_code  \
# 0                   930                 NaN                      NaN
# 1                 34170                 NaN                      NaN
# 2                  6335                 NaN                      NaN
# 3                  3606                 NaN                      NaN
# 4                  6419                 NaN                      NaN
#
#   cand_publication_date  cand_publication_day  cand_publication_month  \
# 0                   NaN                   NaN                     NaN
# 1                   NaN                   NaN                     NaN
# 2                   NaN                   NaN                     NaN
# 3                   NaN                   NaN                     NaN
# 4                   NaN                   NaN                     NaN
#
#    cand_publication_year cand_publisher cand_publisher_code  \
# 0                    NaN            NaN                 NaN
# 1                    NaN            NaN                 NaN
# 2                    NaN            NaN                 NaN
# 3                    NaN            NaN                 NaN
# 4                    NaN            NaN                 NaN
#
#   cand_publisher_studio_label cand_recall_description  \
# 0                    Lightess                     NaN
# 1                         NaN                     NaN
# 2                     Pokemon                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
#    cand_recall_external_identifier  cand_recall_notice_expiration_date  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
#
#    cand_recall_notice_publication_date  cand_recall_notice_receive_date  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cand_target_gender  cand_unit_count      cand_upc  \
# 0                NaN              NaN  7.420000e+11
# 1                NaN              NaN           NaN
# 2                NaN              NaN  7.220000e+11
# 3                NaN              NaN  8.150000e+11
# 4                NaN              NaN  7.980000e+11
#
#   cand_variation_theme_description  cand_variation_theme_id  \
# 0                            COLOR                      2.0
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                       COLOR_NAME                      8.0
#
#    cand_video_game_region cand_video_game_region_description  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#   cand_wireless_provider cand_wireless_provider_code cand_pkg_dimensional_uom  \
# 0                    NaN                         NaN                   inches
# 1                    NaN                         NaN                      NaN
# 2                    NaN                         NaN                   inches
# 3                    NaN                         NaN                   inches
# 4                    NaN                         NaN                   inches
#
#    cand_pkg_height  cand_pkg_length  cand_pkg_weight cand_pkg_weight_uom  \
# 0         5.120000        13.000000         2.819712              pounds
# 1         3.470359        12.572308         6.236240                 NaN
# 2         0.196850        12.007874         0.050706              pounds
# 3         1.600000         5.800000         0.260000              pounds
# 4         9.500000        14.300000        12.700000              pounds
#
#    cand_pkg_width cand_release_date_embargo_level cand_dw_creation_date  \
# 0       10.000000                             NaN             12-Mar-16
# 1        7.714382                             NaN              3-Mar-16
# 2        8.897638                             NaN             14-Feb-17
# 3        2.100000                             NaN             13-Oct-16
# 4       14.200000                             NaN              9-May-15
#
#   cand_dw_last_updated cand_is_deleted cand_last_updated  cand_version  \
# 0            27-Feb-18               N         26-Feb-18           181
# 1            31-Aug-17               Y         30-Aug-17            16
# 2             4-Mar-17               N          4-Mar-17             9
# 3             8-Feb-18               N          8-Feb-18           157
# 4            21-Mar-18               N         20-Mar-18           212
#
#   cand_external_testing_certification
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN

# %% [markdown]
# Selecting numerical columns below.

# %%
X_train = training_features_df[['key_item_width', 'key_item_height', 'key_item_length', 'key_item_weight', 'key_item_package_quantity', 'key_pkg_height', 'key_pkg_length', 'key_pkg_weight', 'key_pkg_width',
                                'cand_item_width', 'cand_item_height', 'cand_item_length', 'cand_item_weight', 'cand_item_package_quantity', 'cand_pkg_height', 'cand_pkg_length', 'cand_pkg_weight', 'cand_pkg_width']].values
y_train = training_data['label'].values

# %% [markdown]
# ___
# ## 5. Fitting the classifier
#
# We will use the K Nearest Neighbors Classifier from sklearn library: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
#
# Things to do in this section:
# * Initialize the classifer and fit your training data to it below.

# %%
# Enter your code here
from sklearn.neighbors import KNeighborsClassifier

print("Training data shape:", X_train.shape)
print("Training label shape:", y_train.shape)

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
# Out:
# Training data shape: (41400, 18)
# Training label shape: (41400,)
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
train_preds = knn.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_train, train_preds))
# Out:
# [[15337  4997]
#  [ 3587 17479]]

# %% [markdown]
# ___
# ## 6. Getting test predictions
#
# In this section, you will use your test_features and make predictions using our trained KNN classifier.
# * Use __knnClassifier.predict()__

# %%
test_features_df = pd.DataFrame(test_features, columns=concat_columns)

# %%
# Enter your code here
X_test = test_features_df[['key_item_width', 'key_item_height', 'key_item_length', 'key_item_weight', 'key_item_package_quantity', 'key_pkg_height', 'key_pkg_length', 'key_pkg_weight', 'key_pkg_width',
                                'cand_item_width', 'cand_item_height', 'cand_item_length', 'cand_item_weight', 'cand_item_package_quantity', 'cand_pkg_height', 'cand_pkg_length', 'cand_pkg_weight', 'cand_pkg_width']].values

test_preds = knn.predict(X_test)

# %%
test_preds[0:5]
# Out:
# array([0, 0, 0, 1, 1])

# %%
len(test_preds)
# Out:
# 4600

# %%
len(test_data)
# Out:
# 4600

# %% [markdown]
# _____
# ## 7. Writing results to a CSV file for leaderboard submission:
# Let's write our test predictions to a CSV file. You will submit this file to [Leaderboard using this link](https://leaderboard.corp.amazon.com/tasks/478/submit)

# %%
import pandas as pd

result_df = pd.DataFrame(columns=["ID", "label"])
result_df["ID"] = test_data["ID"].tolist()
result_df["label"] = test_preds
result_df.to_csv("results.csv", index=False)

# %% [markdown]
# ## 8. Ideas for improvement:
# * Tune K parameter: You can use the train-test split function [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) and search for optimum K value using your validation performance.
# * Try different combinations of features instead of concatenating them in __getFeatures()__. For example: The item-wise difference.

# %%
# try item-wise difference
# try filtering out outliers
# use package group and such
